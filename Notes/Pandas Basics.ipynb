# %% [markdown]
# # DataFrame Basics

# %%
## importing the library 
import pandas as pd

# %%
#Loading the data
df = pd.read_csv("Airline Dataset Updated - v2.csv")
df.head() ## prints the 1st five rows
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate    Male   67      Russia
# 3       BRS38V   Dominica      Pyle  Female   71       China
# 4       9kvTLo        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# 1               NAM  North America     12/26/2022             YCO
# ...

# %%
df.tail() # prints the last 5 rows
# Out:
#       Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 98614       hnGQ62      Gareth    Mugford    Male   85       China
# 98615       2omEzh       Kasey   Benedict  Female   19      Russia
# 98616       VUPiVG      Darrin     Lucken    Male   65   Indonesia
# 98617       E47NtS       Gayle  Lievesley  Female   34       China
# 98618       8JYEcz  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 98614               Hasvik Airport                   NO              Norway
# 98615          Ampampamena Airport                   MG          Madagascar
# 98616  Albacete-Los Llanos Airport                   ES               Spain
# 98617               Gagnoa Airport                   CI       Côte d'Ivoire
# 98618          Yoshkar-Ola Airport                   RU  Russian Federation
#
#       Airport Continent Continents Departure Date Arrival Airport  \
# ...

# %%
## get the rows and columns of the dataframe
df.shape
# Out:
# (98619, 15)

# %%
df[1:3] ## performing slicing operation
# Out:
#   Passenger ID First Name Last Name Gender  Age Nationality  \
# 1       jkXXAX     Elwood      Catt   Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate   Male   67      Russia
#
#              Airport Name Airport Country Code Country Name Airport Continent  \
# 1       Kugluktuk Airport                   CA       Canada               NAM
# 2  Grenoble-Isère Airport                   FR       France                EU
#
#       Continents Departure Date Arrival Airport       Pilot Name Flight Status
# 1  North America     12/26/2022             YCO  Marla Parsonage       On Time
# 2         Europe      1/18/2022             GNB     Rhonda Amber       On Time

# %%
df.columns ## printing the column names
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='object')

# %%
df['Flight Status'] ## gives length of the column and its datatype
# Out:
# 0          On Time
# 1          On Time
# 2          On Time
# 3          Delayed
# 4          On Time
#            ...
# 98614    Cancelled
# 98615    Cancelled
# 98616      On Time
# 98617    Cancelled
# 98618      Delayed
# Name: Flight Status, Length: 98619, dtype: object

# %%
## to get only datatype of the column 
type(df['Flight Status'])
# Out:
# pandas.core.series.Series

# %%
df[['Flight Status', 'Departure Date','Pilot Name']]
# Out:
#       Flight Status Departure Date           Pilot Name
# 0           On Time      6/28/2022  Fransisco Hazeldine
# 1           On Time     12/26/2022      Marla Parsonage
# 2           On Time      1/18/2022         Rhonda Amber
# 3           Delayed      9/16/2022       Kacie Commucci
# 4           On Time      2/25/2022          Ebonee Tree
# ...             ...            ...                  ...
# 98614     Cancelled     12-11-2022     Pammie Kingscote
# 98615     Cancelled     10/30/2022       Dorice Lochran
# 98616       On Time     09-10-2022         Gearalt Main
# 98617     Cancelled     10/26/2022         Judon Chasle
# 98618       Delayed      4/16/2022      Auguste Tindley
#
# [98619 rows x 3 columns]

# %% [markdown]
# # operations on the dataframe

# %%
df['Age'].max()
# Out:
# 90

# %%
df[df['Age'] <= 10]
# Out:
#       Passenger ID  First Name    Last Name  Gender  Age Nationality  \
# 25          f27tyG     Joellyn      Stutter  Female    8     Croatia
# 28          uoKrdd    Jessamyn      Buddles  Female    6        Peru
# 35          L0fKMv    Gardiner    Ferbrache    Male    9      Sweden
# 71          udSiKS     Fidelio       Guerry    Male    3       China
# 80          phfnHI      Cordie  Rosenberger  Female    3      Brazil
# ...            ...         ...          ...     ...  ...         ...
# 98594       cxDx66         Ban      Rottger    Male    5       Spain
# 98596       H3HzS1     Giselle       Peyton  Female    7       Egypt
# 98605       7t9cZR    Morganne     Ockenden  Female    7       China
# 98607       rqUg8x     Rosalie      Waldock  Female    6    Thailand
# 98618       8JYEcz  Wilhelmine       Touret  Female   10      Poland
#
#                      Airport Name Airport Country Code        Country Name  \
# ...

# %%
df['First Name'][df['Age'] == df['Age'].max()]
# Out:
# 170       Pamella
# 199        Sydney
# 206        Vernen
# 273       Mariann
# 358      Jermaine
#            ...
# 98092         Ian
# 98211      Linnet
# 98226     Filippo
# 98253       Marve
# 98552       Liuka
# Name: First Name, Length: 1076, dtype: object

# %%
df[df['Age'] == df['Age'].max()]
# Out:
#       Passenger ID First Name  Last Name  Gender  Age         Nationality  \
# 170         to75jW    Pamella      Eaden  Female   90           Indonesia
# 199         Zlsjqw     Sydney    MacGhee    Male   90           Guatemala
# 206         aogYWd     Vernen   Ivakhnov    Male   90               China
# 273         X0basI    Mariann     Moogan  Female   90         Philippines
# 358         N7DLfQ   Jermaine     Escott    Male   90            Portugal
# ...            ...        ...        ...     ...  ...                 ...
# 98092       uQoe6n        Ian  Proudlove    Male   90              Gambia
# 98211       aIaf11     Linnet     Reedie  Female   90         South Korea
# 98226       FOn03V    Filippo       Pays    Male   90            Colombia
# 98253       Ic4WhE      Marve    Mongain    Male   90           Indonesia
# 98552       D1q05w      Liuka    Caffrey  Female   90  Dominican Republic
#
#                              Airport Name Airport Country Code  \
# ...

# %%
df['Age'].std()
# Out:
# 25.929848552073015

# %%
df['Flight Status'].max()
# Out:
# 'On Time'

# %%
df.describe()
# Out:
#                 Age
# count  98619.000000
# mean      45.504021
# std       25.929849
# min        1.000000
# 25%       23.000000
# 50%       46.000000
# 75%       68.000000
# max       90.000000

# %% [markdown]
# # List of all pandas operations
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html

# %% [markdown]
# # set_index

# %%
df.set_index('Departure Date')
# Out:
#                Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# Departure Date
# 6/28/2022            ABVWIg      Edithe     Leggis  Female   62       Japan
# 12/26/2022           jkXXAX      Elwood       Catt    Male   62   Nicaragua
# 1/18/2022            CdUz2g       Darby    Felgate    Male   67      Russia
# 9/16/2022            BRS38V    Dominica       Pyle  Female   71       China
# 2/25/2022            9kvTLo         Bay    Pencost    Male   21       China
# ...                     ...         ...        ...     ...  ...         ...
# 12-11-2022           hnGQ62      Gareth    Mugford    Male   85       China
# 10/30/2022           2omEzh       Kasey   Benedict  Female   19      Russia
# 09-10-2022           VUPiVG      Darrin     Lucken    Male   65   Indonesia
# 10/26/2022           E47NtS       Gayle  Lievesley  Female   34       China
# 4/16/2022            8JYEcz  Wilhelmine     Touret  Female   10      Poland
#
# ...

# %%
df.set_index('Departure Date', inplace = True)

# %%
df
# Out:
#                Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# Departure Date
# 6/28/2022            ABVWIg      Edithe     Leggis  Female   62       Japan
# 12/26/2022           jkXXAX      Elwood       Catt    Male   62   Nicaragua
# 1/18/2022            CdUz2g       Darby    Felgate    Male   67      Russia
# 9/16/2022            BRS38V    Dominica       Pyle  Female   71       China
# 2/25/2022            9kvTLo         Bay    Pencost    Male   21       China
# ...                     ...         ...        ...     ...  ...         ...
# 12-11-2022           hnGQ62      Gareth    Mugford    Male   85       China
# 10/30/2022           2omEzh       Kasey   Benedict  Female   19      Russia
# 09-10-2022           VUPiVG      Darrin     Lucken    Male   65   Indonesia
# 10/26/2022           E47NtS       Gayle  Lievesley  Female   34       China
# 4/16/2022            8JYEcz  Wilhelmine     Touret  Female   10      Poland
#
# ...

# %%
df.index
# Out:
# Index(['6/28/2022', '12/26/2022', '1/18/2022', '9/16/2022', '2/25/2022',
#        '06-10-2022', '10/30/2022', '04-07-2022', '8/20/2022', '04-06-2022',
#        ...
#        '4/23/2022', '08-05-2022', '06-06-2022', '3/17/2022', '05-12-2022',
#        '12-11-2022', '10/30/2022', '09-10-2022', '10/26/2022', '4/16/2022'],
#       dtype='object', name='Departure Date', length=98619)

# %%
df.loc['6/26/2022']
# Out:
#                Passenger ID  First Name   Last Name  Gender  Age  \
# Departure Date
# 6/26/2022            oQ85WQ     Dorella        Nund  Female   75
# 6/26/2022            ydvBmF  Kristoffer  Kitchinham    Male   68
# 6/26/2022            33MTLm      Stacee      Dulson    Male   88
# 6/26/2022            lgyDZo        Flss  Keenlyside  Female   64
# 6/26/2022            xWU5nL    Florenza     Trotton  Female   85
# ...                     ...         ...         ...     ...  ...
# 6/26/2022            MB7plG       Artie       Wilby    Male   54
# 6/26/2022            vCz7nI  Hyacinthia    Wickling  Female   79
# 6/26/2022            gMw1eg      Hamish      Sullly    Male   89
# 6/26/2022            ptBiPc       Sayre      Gergus  Female    1
# 6/26/2022            e3CHO7      Dorian      Amoore  Female   75
#
#                    Nationality                         Airport Name  \
# Departure Date
# 6/26/2022                China                Jacquinot Bay Airport
# ...

# %%
df.reset_index(inplace = True)
df.head()
# Out:
#   Departure Date Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0      6/28/2022       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1     12/26/2022       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2      1/18/2022       CdUz2g      Darby   Felgate    Male   67      Russia
# 3      9/16/2022       BRS38V   Dominica      Pyle  Female   71       China
# 4      2/25/2022       9kvTLo        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Arrival Airport           Pilot Name  \
# ...
